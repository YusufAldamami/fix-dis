# %% [markdown]
# <a href="https://colab.research.google.com/github/YusufAldamami/ev-data/blob/main/EDA%20documentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
url='https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD'

# %% [markdown]
# ## Cleaning and prep for Washington State ev project
#
#
# First I'll load the dataset. Then, I'll filter out all cars that are not from Washington State. To only want to analyze data revelant to Washington.

# %%
import pandas as pd

#load the dataset from the URL due to large upload size
df=pd.read_csv(url)

#filter the DF to include only rows where the 'State' column is 'WA'
df_wa=df[df['State']=='WA']

#display the first few rows of the filtered DataFrame
display(df_wa.head())
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year     Make  \
# 0  3C3CFFGE1G    Yakima   Yakima    WA      98908.0        2016     FIAT
# 1  WP0AB2Y16L      King   Auburn    WA      98092.0        2020  PORSCHE
# 2  5YJ3E1EB2J      King  Seattle    WA      98109.0        2018    TESLA
# 3  5YJYGDEF5L      King  Seattle    WA      98125.0        2020    TESLA
# 4  5YJXCBE22J  Thurston  Olympia    WA      98501.0        2018    TESLA
#
#      Model           Electric Vehicle Type  \
# 0      500  Battery Electric Vehicle (BEV)
# 1   TAYCAN  Battery Electric Vehicle (BEV)
# 2  MODEL 3  Battery Electric Vehicle (BEV)
# 3  MODEL Y  Battery Electric Vehicle (BEV)
# 4  MODEL X  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            84.0
# 1           Clean Alternative Fuel Vehicle Eligible           203.0
# 2           Clean Alternative Fuel Vehicle Eligible           215.0
# 3           Clean Alternative Fuel Vehicle Eligible           291.0
# 4           Clean Alternative Fuel Vehicle Eligible           238.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  14.0       180778377
# 1        0.0                  47.0       277717723
# 2        0.0                  36.0       475865722
# 3        0.0                  46.0       108837249
# 4        0.0                  22.0       259851259
#
#               Vehicle Location                               Electric Utility  \
# 0  POINT (-120.60199 46.59817)                                     PACIFICORP
# 1  POINT (-122.18497 47.28825)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2  POINT (-122.35022 47.63824)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3  POINT (-122.30253 47.72656)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.89165 47.03954)                         PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303303e+10
# 2       5.303301e+10
# 3       5.303300e+10
# 4       5.306701e+10

# %% [markdown]
# ## Drop State Column
#
#
# Since i already filtered for Washington State cars, the 'State' column is no longer needed.

# %%
df_wa=df_wa.drop(columns=['State'])

#DataFrame after dropping 'State' column
display(df_wa.head())
# Out:
#    VIN (1-10)    County     City  Postal Code  Model Year     Make    Model  \
# 0  3C3CFFGE1G    Yakima   Yakima      98908.0        2016     FIAT      500
# 1  WP0AB2Y16L      King   Auburn      98092.0        2020  PORSCHE   TAYCAN
# 2  5YJ3E1EB2J      King  Seattle      98109.0        2018    TESLA  MODEL 3
# 3  5YJYGDEF5L      King  Seattle      98125.0        2020    TESLA  MODEL Y
# 4  5YJXCBE22J  Thurston  Olympia      98501.0        2018    TESLA  MODEL X
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
# 2  Battery Electric Vehicle (BEV)
# 3  Battery Electric Vehicle (BEV)
# 4  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            84.0
# 1           Clean Alternative Fuel Vehicle Eligible           203.0
# 2           Clean Alternative Fuel Vehicle Eligible           215.0
# 3           Clean Alternative Fuel Vehicle Eligible           291.0
# 4           Clean Alternative Fuel Vehicle Eligible           238.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  14.0       180778377
# 1        0.0                  47.0       277717723
# 2        0.0                  36.0       475865722
# 3        0.0                  46.0       108837249
# 4        0.0                  22.0       259851259
#
#               Vehicle Location                               Electric Utility  \
# 0  POINT (-120.60199 46.59817)                                     PACIFICORP
# 1  POINT (-122.18497 47.28825)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2  POINT (-122.35022 47.63824)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3  POINT (-122.30253 47.72656)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.89165 47.03954)                         PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303303e+10
# 2       5.303301e+10
# 3       5.303300e+10
# 4       5.306701e+10

# %% [markdown]
# ## Check and Handling any Missing Values
#
#
# I'll check for any missing information in the dataset.
# If there are missing values I'll decide on a simple way to handle them.

# %%
#Missing values before handling
display(df_wa.isnull().sum())
# Out:
# VIN (1-10)                                            0
# County                                                0
# City                                                  0
# Postal Code                                           0
# Model Year                                            0
# Make                                                  0
# Model                                                 0
# Electric Vehicle Type                                 0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     0
# Electric Range                                        4
# Base MSRP                                             4
# Legislative District                                  0
# DOL Vehicle ID                                        0
# Vehicle Location                                     78
# Electric Utility                                      0
# 2020 Census Tract                                     0
# dtype: int64

# %%
df_wa.dropna(subset=['Electric Range','Base MSRP','Vehicle Location'],inplace=True)

#Missing values after handling'
display(df_wa.isnull().sum())
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %% [markdown]
# ## Correcting The Data Types
#
# I'll look at the columns and make sure they have the right type of data. eg: if a column should be numbers I'll make sure it's not text so i can do calculations correctly.

# %%
#Data types before conversion
display(df_wa.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 268927 entries, 0 to 269672
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         268927 non-null  object
#  1   County                                             268927 non-null  object
#  2   City                                               268927 non-null  object
#  3   Postal Code                                        268927 non-null  float64
#  4   Model Year                                         268927 non-null  int64
#  5   Make                                               268927 non-null  object
#  6   Model                                              268927 non-null  object
#  7   Electric Vehicle Type                              268927 non-null  object
#  8   Clean Alternative Fuel Vehicle (CAFV) Eligibility  268927 non-null  object
#  9   Electric Range                                     268927 non-null  float64
#  10  Base MSRP                                          268927 non-null  float64
#  11  Legislative District                               268927 non-null  float64
#  12  DOL Vehicle ID                                     268927 non-null  int64
#  13  Vehicle Location                                   268927 non-null  object
#  14  Electric Utility                                   268927 non-null  object
#  15  2020 Census Tract                                  268927 non-null  float64
# dtypes: float64(5), int64(2), object(9)
# memory usage: 34.9+ MB
# None

# %%
import pandas as pd

df_wa['Model Year']=pd.to_numeric(df_wa['Model Year'],errors='coerce')
df_wa['Electric Range']=pd.to_numeric(df_wa['Electric Range'],errors='coerce')
df_wa['Base MSRP']=pd.to_numeric(df_wa['Base MSRP'],errors='coerce')

#Converting 'Model Year' to a whole number type that can handle missing values to make sure its correct for filtering
if df_wa['Model Year'].isnull().any():
    df_wa['Model Year']=df_wa['Model Year'].astype('Int64') #handling whole numbers with possible missing entries
else:
    df_wa['Model Year']=df_wa['Model Year'].astype('int64')
#Data types after conversion and error handling
display(df_wa.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 268927 entries, 0 to 269672
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         268927 non-null  object
#  1   County                                             268927 non-null  object
#  2   City                                               268927 non-null  object
#  3   Postal Code                                        268927 non-null  float64
#  4   Model Year                                         268927 non-null  int64
#  5   Make                                               268927 non-null  object
#  6   Model                                              268927 non-null  object
#  7   Electric Vehicle Type                              268927 non-null  object
#  8   Clean Alternative Fuel Vehicle (CAFV) Eligibility  268927 non-null  object
#  9   Electric Range                                     268927 non-null  float64
#  10  Base MSRP                                          268927 non-null  float64
#  11  Legislative District                               268927 non-null  float64
#  12  DOL Vehicle ID                                     268927 non-null  int64
#  13  Vehicle Location                                   268927 non-null  object
#  14  Electric Utility                                   268927 non-null  object
#  15  2020 Census Tract                                  268927 non-null  float64
# dtypes: float64(5), int64(2), object(9)
# memory usage: 34.9+ MB
# None

# %% [markdown]
# ## Basic Descriptive Statistics
#
#
# To start understanding our cleaned data I'll calculate some basic summary statistics for the numerical columns. For an overview of the dataset

# %%
#Descriptive statistics for numerical columns
display(df_wa.describe())
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  268927.000000  268927.000000   268927.000000  268927.000000
# mean    98273.588483    2021.926367       40.757503     662.732303
# std       314.217880       3.051221       79.604061    6790.024718
# min     98001.000000    1999.000000        0.000000       0.000000
# 25%     98052.000000    2021.000000        0.000000       0.000000
# 50%     98133.000000    2023.000000        0.000000       0.000000
# 75%     98382.000000    2024.000000       33.000000       0.000000
# max     99403.000000    2026.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         268927.000000    2.689270e+05       2.689270e+05
# mean              28.853551    2.434541e+08       5.304012e+10
# std               14.896005    6.463959e+07       1.658332e+07
# min                1.000000    4.385000e+03       5.300195e+10
# 25%               17.000000    2.190650e+08       5.303301e+10
# 50%               32.000000    2.611059e+08       5.303303e+10
# 75%               42.000000    2.768578e+08       5.305394e+10
# max               49.000000    4.791150e+08       5.307794e+10

# %% [markdown]
# ## Visualize Distribution of Model Year
#
# I want to see how the 'Model Year' of cars is distributed. I'll create a  histogram using matplotlib to show which model years are most common in our dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df_wa['Model Year'],bins=range(df_wa['Model Year'].min(),df_wa['Model Year'].max()+2),edgecolor='black')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.title('Distribution of EV Model Years')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize Distribution of the Electric Range
#
# I'll create a histogram to visualize the distribution of 'Electric Range' to understand the Ev ranges among vehicles in the dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df_wa['Electric Range'],bins=50,edgecolor='black')
plt.xlabel('Electric Range')
plt.ylabel('Number of Vehicles')
plt.title('EV Range in Washington')
plt.grid(axis='y',alpha=0.75)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing the Distribution of the Base MSRP
#
#
# I'll create a histogram to visualize the distribution of 'Base MSRP'.
# This will make me understand the common price points for electric vehicles in our dataset.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(df_wa['Base MSRP'],bins=50,edgecolor='black')
plt.xlabel('Base MSRP)')
plt.ylabel('Number of Vehicles')
plt.title('Distribution of Evs Base MSRP')
plt.grid(axis='y',alpha=0.75)
plt.tight_layout()
plt.show() #We see many 0 values due to poor entry

# %% [markdown]
# ## Comparing Electric Range and Base MSRP
#
#
# I'll create a scatter plot to visualize the relationship between 'Electric Range' and 'Base MSRP'. The dots will help identify any patterns between how far an electric vehicle can go and its price.

# %%
import matplotlib.pyplot as plt

#Filter out rows where 'Base MSRP' is 0 due to misleading charts before
plot_df = df_wa[df_wa['Base MSRP']>0][['Electric Range','Base MSRP']]

plt.figure(figsize=(10, 6))
plt.scatter(plot_df['Electric Range'],plot_df['Base MSRP'],alpha=0.5)
plt.xlabel('Electric Range')
plt.ylabel('Base MSRP')
plt.title('Range and Base MSRP Comparision')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Compare 'Model Year' and 'Base MSRP'
#
# I'll create a scatter plot to visualize the relationship between 'Model Year' and 'Base MSRP'.
# Same as before to see any correlation

# %%
import matplotlib.pyplot as plt

#Filtering out rows where 'Base MSRP' is 0 for accurate charts
plot_df_year_price=df_wa[df_wa['Base MSRP']>0][['Model Year','Base MSRP']]

plt.figure(figsize=(10,6))
plt.scatter(plot_df_year_price['Model Year'],plot_df_year_price['Base MSRP'],alpha=0.5)
plt.xlabel('Model Year')
plt.ylabel('Base MSRP')
plt.title('Model Year and Base MSRP of EVs')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interactive EV Range Chart with Plotly
#
# ill make a interactive dot chart using plotly to visualize 'Electric Range' against 'Base MSRP'. This will allow us to hover over points and see more details, making the chart more engaging. We'll filter out any cars with a '0' price for this chart.

# %%
import plotly.express as px

#Filtering out 0 values
filtered_df=df_wa[df_wa['Base MSRP']>0]

#Create an interactive scatter plot usuing plotly
fig = px.scatter(
    filtered_df,
    x='Electric Range',
    y='Base MSRP',
    title='Interactive EV Range and Base MSRP',
    hover_data=['Model Year','Make','Model'] )#Adding hover data for more details when placing cursor over any dot

#Display the plot to see if theres a relationship between the 2 variables accurately
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f294e87-6e6f-4455-a6a8-0f69f34b2967" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f294e87-6e6f-4455-a6a8-0f69f34b2967")) {                    Plotly.newPlot(                        "9f294e87-6e6f-4455-a6a8-0f69f34b2967",                        [{"customdata":[[2018,"BMW","330E"],[2014,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2019,"MINI","COUNTRYMAN"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2010,"TESLA","ROADSTER"],[2020,"PORSCHE","CAYENNE"],[2019,"CHRYSLER","PACIFICA"],[2013,"TESLA","MODEL S"],[2019,"SUBARU","CROSSTREK"],[2017,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2016,"KIA","SOUL"],[2018,"MINI","COUNTRYMAN"],[2019,"VOLVO","XC60"],[2018,"BMW","530E"],[2018,"BMW","740E"],[2014,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2018,"VOLVO","XC60"],[2014,"TESLA","MODEL S"],[2019,"BMW","530E"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2019,"BMW","530E"],[2019,"BMW","530E"],[2018,"KIA","SOUL"],[2018,"BMW","330E"],[2017,"BMW","330E"],[2014,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2019,"CHRYSLER","PACIFICA"],[2013,"TESLA","MODEL S"],[2008,"TESLA","ROADSTER"],[2019,"SUBARU","CROSSTREK"],[2013,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2018,"BMW","330E"],[2018,"VOLVO","XC90"],[2018,"VOLVO","XC60"],[2018,"VOLVO","XC90"],[2014,"TESLA","MODEL S"],[2018,"BMW","530E"],[2014,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2018,"MINI","COUNTRYMAN"],[2019,"BMW","530E"],[2018,"BMW","530E"],[2013,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2014,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2019,"BMW","530E"],[2014,"TESLA","MODEL S"],[2018,"PORSCHE","PANAMERA"],[2018,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2019,"SUBARU","CROSSTREK"],[2017,"KIA","SOUL"],[2010,"TESLA","ROADSTER"],[2019,"VOLVO","XC60"],[2017,"KIA","SOUL"],[2012,"TESLA","MODEL S"],[2017,"BMW","740E"],[2018,"KIA","SOUL"],[2019,"CHRYSLER","PACIFICA"],[2016,"KIA","SOUL"],[2016,"KIA","SOUL"],[2019,"BMW","530E"],[2013,"TESLA","MODEL S"],[2019,"BMW","530E"],[2014,"TESLA","MODEL S"],[2018,"MINI","COUNTRYMAN"],[2018,"VOLVO","XC90"],[2010,"TESLA","ROADSTER"],[2014,"TESLA","MODEL S"],[2018,"VOLVO","XC60"],[2018,"BMW","530E"],[2017,"KIA","SOUL"],[2019,"CHRYSLER","PACIFICA"],[2014,"TESLA","MODEL S"],[2018,"VOLVO","XC60"],[2014,"TESLA","MODEL S"],[2018,"VOLVO","XC60"],[2016,"KIA","SOUL"],[2018,"KIA","SOUL"],[2014,"TESLA","MODEL S"],[2017,"KIA","SOUL"],[2014,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2016,"BMW","330E"],[2014,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2011,"TESLA","ROADSTER"],[2017,"KIA","SOUL"],[2016,"KIA","SOUL"],[2014,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2012,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2014,"TESLA","MODEL S"],[2019,"MINI","COUNTRYMAN"],[2018,"BMW","330E"],[2018,"MINI","COUNTRYMAN"],[2018,"PORSCHE","PANAMERA"],[2013,"TESLA","MODEL S"],[2019,"BMW","530E"],[2019,"CHRYSLER","PACIFICA"],[2014,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2018,"KIA","SOUL"],[2020,"PORSCHE","CAYENNE"],[2013,"TESLA","MODEL S"],[2016,"KIA","SOUL"],[2016,"KIA","SOUL"],[2017,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2018,"BMW","530E"],[2012,"TESLA","MODEL S"],[2012,"TESLA","MODEL S"],[2013,"TESLA","MODEL S"],[2018,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2018,"VOLVO","XC60"],[2019,"CHRYSLER","PACIFICA"],[2013,"TESLA","MODEL S"],[2018,"BMW","330E"],[2019,"SUBARU","CROSSTREK"],[2018,"BMW","530E"],[2016,"KIA","SOUL"],[2013,"TESLA","MODEL S"],[2016,"BMW","330E"],[2013,"TESLA","MODEL S"],[2019,"SUBARU","CROSSTREK" ...

# %% [markdown]
# ## Key Findings
#
# 1. The focus was limited to electric cars in Washington State
# 2. Incomplete or incorrect records were taken out
# 3. Important details like year range and price were corrected for consistency
# 4. Charts showed some cars had unrealistic $0 prices
# 5. Once those were removed clearer patterns between cost and range appeared
#
# ## Next Steps
# - Use predictive ML models to estimate how many EVs will be on the road in future years and the energy they will need
